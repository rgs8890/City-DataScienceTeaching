# %% [markdown]
# # Lab 07

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1: Dimension reduction with PCA

# %%
cc_df = pd.read_csv(r"C:\Users\rgs88\OneDrive\Documents\Principles of Data Science\censusCrimeClean2.csv")
cc_df
# Out:
#             communityname  fold  population  householdsize  racepctblack  \
# 0            Lakewoodcity     1        0.19           0.33          0.02
# 1             Tukwilacity     1        0.00           0.16          0.12
# 2            Aberdeentown     1        0.00           0.42          0.49
# 3     Willingborotownship     1        0.04           0.77          1.00
# 4       Bethlehemtownship     1        0.01           0.55          0.02
# ...                   ...   ...         ...            ...           ...
# 1989    TempleTerracecity    10        0.01           0.40          0.10
# 1990          Seasidecity    10        0.05           0.96          0.46
# 1991        Waterburytown    10        0.16           0.37          0.25
# 1992          Walthamcity    10        0.08           0.51          0.06
# 1993          Ontariocity    10        0.20           0.78          0.14
#
#       racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# ...

# %%
communities = cc_df.communityname
communities
# Out:
# 0              Lakewoodcity
# 1               Tukwilacity
# 2              Aberdeentown
# 3       Willingborotownship
# 4         Bethlehemtownship
#                ...
# 1989      TempleTerracecity
# 1990            Seasidecity
# 1991          Waterburytown
# 1992            Walthamcity
# 1993            Ontariocity
# Name: communityname, Length: 1994, dtype: object

# %%
dataframe = cc_df.drop("communityname", axis="columns")
dataframe
# Out:
#       fold  population  householdsize  racepctblack  racePctWhite  \
# 0        1        0.19           0.33          0.02          0.90
# 1        1        0.00           0.16          0.12          0.74
# 2        1        0.00           0.42          0.49          0.56
# 3        1        0.04           0.77          1.00          0.08
# 4        1        0.01           0.55          0.02          0.95
# ...    ...         ...            ...           ...           ...
# 1989    10        0.01           0.40          0.10          0.87
# 1990    10        0.05           0.96          0.46          0.28
# 1991    10        0.16           0.37          0.25          0.69
# 1992    10        0.08           0.51          0.06          0.87
# 1993    10        0.20           0.78          0.14          0.46
#
#       racePctAsian  racePctHisp  agePct12t21  agePct12t29  agePct16t24  ...  \
# 0             0.12         0.17         0.34         0.47         0.29  ...
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2, svd_solver='full')
pca.fit(dataframe)
print(pca.explained_variance_ratio_)
# Out:
# [0.67387831 0.08863102]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(dataframe)
# Out:
# StandardScaler()

# %%
dataframe
# Out:
#       fold  population  householdsize  racepctblack  racePctWhite  \
# 0        1        0.19           0.33          0.02          0.90
# 1        1        0.00           0.16          0.12          0.74
# 2        1        0.00           0.42          0.49          0.56
# 3        1        0.04           0.77          1.00          0.08
# 4        1        0.01           0.55          0.02          0.95
# ...    ...         ...            ...           ...           ...
# 1989    10        0.01           0.40          0.10          0.87
# 1990    10        0.05           0.96          0.46          0.28
# 1991    10        0.16           0.37          0.25          0.69
# 1992    10        0.08           0.51          0.06          0.87
# 1993    10        0.20           0.78          0.14          0.46
#
#       racePctAsian  racePctHisp  agePct12t21  agePct12t29  agePct16t24  ...  \
# 0             0.12         0.17         0.34         0.47         0.29  ...
# ...

# %% [markdown]
# ## Exercise 2: Multidimensional Scaling

# %% [markdown]
# ## Exercise 3: Group Wines based on their characteristics

# %% [markdown]
# ## Exercise 4: Cross Validation
