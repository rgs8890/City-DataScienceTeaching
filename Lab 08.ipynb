# %% [markdown]
# # Lab 08

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rgs88\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rgs88\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
from urllib.request import urlopen
target_url0 = 'http://www.gutenberg.org/files/135/135-0.txt'
book_raw = urlopen(target_url0).read().decode('utf-8')

# %%
type(book_raw)
# Out:
# str

# %%
len(book_raw)
# Out:
# 3324222

# %%
book_raw[1:250]
# Out:
# 'The Project Gutenberg eBook of Les Misérables, by Victor Hugo\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it aw'

# %%
from nltk.tokenize import word_tokenize
word_tokens = word_tokenize(book_raw)

# %%
print(book_raw[1:200])
# Out:
# The Project Gutenberg eBook of Les Misérables, by Victor Hugo
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no res

# %%
print(word_tokens[1:40])
# Out:
# ['Project', 'Gutenberg', 'eBook', 'of', 'Les', 'Misérables', ',', 'by', 'Victor', 'Hugo', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'United', 'States', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever']

# %%
from nltk.corpus import stopwords
stop_words = (stopwords.words('english'))

# %% [markdown]
# ## Lengthy Books

# %% [markdown]
# ## Book 2

# %%
target_url1 = "https://www.gutenberg.org/files/1184/1184-0.txt"
book_raw2 = urlopen(target_url1).read().decode('utf-8')

# %%
type(book_raw2)
# Out:
# str

# %%
len(book_raw2)
# Out:
# 2708279

# %% [markdown]
# This book has less words than the e_book of les miserables.

# %%
from nltk.tokenize import sent_tokenize
Miserables_sentences = sent_tokenize(book_raw2)

# %%
from nltk.corpus import stopwords
Miserables_sentences_filtered = []
for sentence in Miserables_sentences:
    lst = [word for word in sentence.split() if word not in stop_words]
    Miserables_sentences_filtered.append(lst)

# %%
Miserables_sentences_filtered
# Out:
# [['\ufeffThe',
#   'Project',
#   'Gutenberg',
#   'eBook',
#   'The',
#   'Count',
#   'Monte',
#   'Cristo,',
#   'Alexandre',
#   'Dumas,',
#   'père',
#   'This',
#   'eBook',
#   'use',
#   'anyone',
#   'anywhere',
#   'United',
#   'States',
#   'parts',
#   'world',
#   'cost',
#   'almost',
#   'restrictions',
#   'whatsoever.'],
#  ['You',
#   'may',
#   'copy',
#   'it,',
#   'give',
#   'away',
#   're-use',
#   'terms',
#   'Project',
#   'Gutenberg',
#   'License',
#   'included',
#   'eBook',
#   'online',
#   'www.gutenberg.org.'],
#  ['If',
#   'located',
#   'United',
#   'States,',
#   'check',
#   'laws',
#   'country',
#   'located',
#   'using',
#   'eBook.'],
#  ['Title:',
#   'The',
#   'Count',
#   'Monte',
#   'Cristo',
#   'Author:',
#   'Alexandre',
#   'Dumas,',
#   'père',
#   'Release',
#   'Date:',
#   'January,',
#   '1998',
#   '[eBook',
#   '#1184]',
#   '[Last',
#   'updated:',
#   'October',
#   '14,',
#   '2022]',
#   'Language:',
#   'English',
# ...

# %% [markdown]
# ## Book 3

# %%
target_url2 = "https://www.gutenberg.org/files/2600/2600-0.txt"
book_raw3 = urlopen(target_url2).read().decode('utf-8')

# %%
type(book_raw3)
# Out:
# str

# %%
len(book_raw3)
# Out:
# 3293552

# %%
from nltk.tokenize import sent_tokenize
Leo_Tolstoy_sentences = sent_tokenize(book_raw3)

# %%
number_of_sentences = len(Leo_Tolstoy_sentences)
number_of_sentences
# Out:
# 26548

# %%
lengths = [len(sentence) for sentence in Leo_Tolstoy_sentences]

# %%
average_length = sum(lengths)/len(lengths)
average_length
# Out:
# 121.96459243634172

# %% [markdown]
# ## Book 4

# %%
target_url3 = "https://www.gutenberg.org/cache/epub/996/pg996.txt"

# %%
book_raw4 = urlopen(target_url3).read().decode('utf-8')

# %%
len(book_raw4)
# Out:
# 2361806

# %%
from nltk.tokenize import sent_tokenize
don_quijote = sent_tokenize(book_raw4)

# %%
don_quijote[0]
# Out:
# '\ufeffThe Project Gutenberg eBook of The History of Don Quixote, by Miguel de Cervantes\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever.'

# %%
from nltk import FreqDist

# %%
from nltk.tokenize import word_tokenize

# %%
for i in don_quijote:
    don_quijote_words = word_tokenize(i)

# %%
don_quijote_words
# Out:
# ['Most',
#  'people',
#  'start',
#  'at',
#  'our',
#  'website',
#  'which',
#  'has',
#  'the',
#  'main',
#  'PG',
#  'search',
#  'facility',
#  ':',
#  'www.gutenberg.org',
#  'This',
#  'website',
#  'includes',
#  'information',
#  'about',
#  'Project',
#  'Gutenberg-tm',
#  ',',
#  'including',
#  'how',
#  'to',
#  'make',
#  'donations',
#  'to',
#  'the',
#  'Project',
#  'Gutenberg',
#  'Literary',
#  'Archive',
#  'Foundation',
#  ',',
#  'how',
#  'to',
#  'help',
#  'produce',
#  'our',
#  'new',
#  'eBooks',
#  ',',
#  'and',
#  'how',
#  'to',
#  'subscribe',
#  'to',
#  'our',
#  'email',
#  'newsletter',
#  'to',
#  'hear',
#  'about',
#  'new',
#  'eBooks',
#  '.']

# %%
from nltk import FreqDist
fdist = FreqDist(don_quijote_words)

# %%
fdist
# Out:
# FreqDist({'to': 6, 'our': 3, ',': 3, 'how': 3, 'website': 2, 'the': 2, 'about': 2, 'Project': 2, 'new': 2, 'eBooks': 2, ...})

# %% [markdown]
# # Exercise 2

# %%
from PIL import Image
mask_word = np.array(Image.open(r"C:\Users\rgs88\OneDrive\Documents\Victor_Hugo_Buste_David_27122012.jpg"))

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width = 1000, height = 700,
                      background_color = 'black', mask=mask_word, colormap = plt.cm.summer,
                      min_font_size = 10).generate(str(don_quijote))
plt.imshow(wordcloud)

# %% [markdown]
# The wordcloud created represents many different words in the book by don_quijote, and we use matplotlib to plot the wordcloud.

# %%
import requests
url = 'https://www.gutenberg.org/files/1184/1184-0.txt'
les_miserables = requests.get(url)
print(les_miserables.text)
count_les_miserables = len(les_miserables.split())
print("The number of words in les miserables is:", count_les_miserables)
