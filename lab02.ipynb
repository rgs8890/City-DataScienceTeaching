# %% [markdown]
# # Data Characteristics and Wrangling Exercises

# %% [markdown]
# ## Part 1 : Pandas Basics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
passengerfile = pd.read_csv("C:/Users/rgs88/Documents/Principles of Data Science/passengerData.csv")

# %%
ticketprices = pd.read_csv("C:/Users/rgs88/Documents/Principles of Data Science/ticketPrices.csv")

# %%
DF = pd.merge(passengerfile, ticketprices, on='TicketType')
DF
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
five_oldest = DF.sort_values(by='Age', ascending=False).head()
five_oldest
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 747          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 442          852         0       3                   Svensson, Mr. Johan
# 12            97         0       1             Goldschmidt, Mr. George B
# 619          494         0       1               Artagaveytia, Mr. Ramon
# 461          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  TicketType  Fare
# 747  male  80.0           7    87
# 442  male  74.0           4    22
# 12   male  71.0           1    33
# 619  male  71.0           6    66
# 461  male  70.5           5    14

# %%
five_oldest_names = five_oldest['Name']
five_oldest_names
# Out:
# 747    Barkworth, Mr. Algernon Henry Wilson
# 442                     Svensson, Mr. Johan
# 12                Goldschmidt, Mr. George B
# 619                 Artagaveytia, Mr. Ramon
# 461                    Connors, Mr. Patrick
# Name: Name, dtype: object

# %%
plt.scatter(DF.Fare,DF.Age)

# %%
prelim1_df = DF[DF["Sex"]=="female"]

# %%
women45_df = prelim1_df[(prelim1_df['Age'] >= 40) & (prelim1_df['Age'] <= 50)]
women45_df
# Out:
#      PassengerId  Survived  Pclass  \
# 5             41         0       3
# 34           273         1       2
# 54           433         1       2
# 55           441         1       2
# 92           737         0       3
# 107          857         1       1
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 368          260         1       2
# 373          300         1       1
# 401          524         1       1
# 433          780         1       1
# 453           53         1       1
# 463          133         0       3
# 481          277         0       3
# 494          381         1       1
# ...

# %%
final_df = women45_df[(women45_df['Fare'] >= 40)]
final_df
# Out:
#      PassengerId  Survived  Pclass  \
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 700          255         0       3
# 734          527         1       2
# 748          639         0       3
# 752          671         1       2
# 753          679         0       3
# 775          855         0       2
# 776          863         1       1
#
#                                                   Name     Sex   Age  \
# 132  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0
# 134                         Isham, Miss. Ann Elizabeth  female  50.0
# 154                    Burns, Miss. Elizabeth Margaret  female  41.0
# ...

# %%
plt.plot(final_df.Fare, final_df.Name)

# %% [markdown]
# ## Part 2: Missing Values

# %%
titanic_df = pd.read_csv("C:/Users/rgs88/Documents/Principles of Data Science/titanicSurvival_m.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare            46
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  845.000000
# mean     0.381594   32.304319
# std      0.806057   49.792612
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.275000
# max      6.000000  512.329200

# %%
titanic_df2 = titanic_df[['Age','Fare']].fillna('0')

# %%
titanic_df2
# Out:
#       Age     Fare
# 0    22.0     7.25
# 1    38.0  71.2833
# 2    26.0    7.925
# 3    35.0     53.1
# 4    35.0     8.05
# ..    ...      ...
# 886  27.0     13.0
# 887  19.0     30.0
# 888     0    23.45
# 889  26.0     30.0
# 890  32.0     7.75
#
# [891 rows x 2 columns]

# %%
plt.scatter(titanic_df2['Age'],titanic_df2['Fare'])

# %%
mean_age = titanic_df.Age.mean()
mean_fare = titanic_df.Fare.mean()

# %%
titanic_df['Age'].fillna(mean_age)
titanic_df['Fare'].fillna(mean_fare)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.scatter(titanic_df.Age, titanic_df.Fare)

# %% [markdown]
# Differences we can see are:
# 1. Mean graph has less dispersion
# 2. Mean graph has more values closer to line of best fit
# 3. A higher majority of values are lower value in the mean graph than the zero graph.

# %% [markdown]
# ## Part 3: Data Transformations

# %%
WHO_df = pd.read_csv('C:/Users/rgs88/Documents/Principles of Data Science/TB_burden_countries_2014-09-29.csv')
WHO_df.dtypes
# Out:
# country                      object
# iso2                         object
# iso3                         object
# iso_numeric                   int64
# g_whoregion                  object
# year                          int64
# e_pop_num                     int64
# e_prev_100k                 float64
# e_prev_100k_lo              float64
# e_prev_100k_hi              float64
# e_prev_num                  float64
# e_prev_num_lo               float64
# e_prev_num_hi               float64
# e_mort_exc_tbhiv_100k       float64
# e_mort_exc_tbhiv_100k_lo    float64
# e_mort_exc_tbhiv_100k_hi    float64
# e_mort_exc_tbhiv_num        float64
# e_mort_exc_tbhiv_num_lo     float64
# e_mort_exc_tbhiv_num_hi     float64
# source_mort                  object
# e_inc_100k                  float64
# e_inc_100k_lo               float64
# e_inc_100k_hi               float64
# e_inc_num                   float64
# e_inc_num_lo                float64
# e_inc_num_hi                float64
# ...

# %%
for col in WHO_df:
        if WHO_df[col].dtype == 'float64':
            WHO_df[col].fillna(WHO_df[col].mean(), inplace = True)
        else:
            WHO_df[col].fillna(0, inplace = True)

# %%
WHO_df
# Out:
#           country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0     Afghanistan   AF  AFG            4         EMR  1990   11731193
# 1     Afghanistan   AF  AFG            4         EMR  1991   12612043
# 2     Afghanistan   AF  AFG            4         EMR  1992   13811876
# 3     Afghanistan   AF  AFG            4         EMR  1993   15175325
# 4     Afghanistan   AF  AFG            4         EMR  1994   16485018
# ...           ...  ...  ...          ...         ...   ...        ...
# 4898     Zimbabwe   ZW  ZWE          716         AFR  2008   12784041
# 4899     Zimbabwe   ZW  ZWE          716         AFR  2009   12888918
# 4900     Zimbabwe   ZW  ZWE          716         AFR  2010   13076978
# 4901     Zimbabwe   ZW  ZWE          716         AFR  2011   13358738
# 4902     Zimbabwe   ZW  ZWE          716         AFR  2012   13724317
#
#       e_prev_100k  e_prev_100k_lo  e_prev_100k_hi  ...  e_inc_tbhiv_100k  \
# ...

# %%
plt.hist(WHO_df['e_prev_100k_hi'], bins=20)
# Out:
# (array([2.523e+03, 7.080e+02, 4.590e+02, 3.120e+02, 2.480e+02, 2.040e+02,
#         1.410e+02, 8.900e+01, 6.200e+01, 2.900e+01, 2.600e+01, 2.500e+01,
#         2.100e+01, 1.700e+01, 1.000e+01, 8.000e+00, 7.000e+00, 9.000e+00,
#         2.000e+00, 3.000e+00]),
#  array([5.400000e-01, 1.787630e+02, 3.569860e+02, 5.352090e+02,
#         7.134320e+02, 8.916550e+02, 1.069878e+03, 1.248101e+03,
#         1.426324e+03, 1.604547e+03, 1.782770e+03, 1.960993e+03,
#         2.139216e+03, 2.317439e+03, 2.495662e+03, 2.673885e+03,
#         2.852108e+03, 3.030331e+03, 3.208554e+03, 3.386777e+03,
#         3.565000e+03]),
#  <BarContainer object of 20 artists>)

# %%
WHO_df2 = WHO_df.select_dtypes(exclude=['object'])
column_means = WHO_df2.mean()
WHO_df2 = WHO_df2.fillna(column_means)
WHO_df_log = np.log(WHO_df2)
# Out:
# C:\Users\rgs88\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)

# %%
normalisedlog_df = (WHO_df_log - WHO_df_log.min())/(WHO_df_log.max()-WHO_df_log.min())

# %%
normalisedlog_df
# Out:
#       iso_numeric      year  e_pop_num  e_prev_100k  e_prev_100k_lo  \
# 0        0.000000  0.000000   0.659953     0.804136        0.746206
# 1        0.000000  0.045694   0.665120     0.814655        0.790395
# 2        0.000000  0.091365   0.671604     0.823117        0.788583
# 3        0.000000  0.137013   0.678322     0.830170        0.798456
# 4        0.000000  0.182638   0.684229     0.835250        0.805415
# ...           ...       ...        ...          ...             ...
# 4898     0.958956  0.818998   0.666086     0.838852        0.674807
# 4899     0.958956  0.864282   0.666669     0.833139        0.661052
# 4900     0.958956  0.909544   0.667703     0.837065        0.697792
# 4901     0.958956  0.954783   0.669224     0.842096        0.727057
# 4902     0.958956  1.000000   0.671151     0.835772        0.725943
#
#       e_prev_100k_hi  e_prev_num  e_prev_num_lo  e_prev_num_hi  \
# 0           0.807361         NaN            NaN       0.790097
# ...

# %% [markdown]
# As we can see, some of the log values are infinite, so a lot of null values are displayed for columns. We must perform this operation but not on the logisitic dataframe.

# %%
normalised_df = (WHO_df2 - WHO_df2.min())/(WHO_df2.max()-WHO_df2.min())

# %%
normalised_df
# Out:
#       iso_numeric      year  e_pop_num  e_prev_100k  e_prev_100k_lo  \
# 0             0.0  0.000000   0.008518     0.175691        0.085051
# 1             0.0  0.045455   0.009158     0.192898        0.130646
# 2             0.0  0.090909   0.010029     0.207954        0.128366
# 3             0.0  0.136364   0.011019     0.221397        0.141285
# 4             0.0  0.181818   0.011970     0.231613        0.151164
# ...           ...       ...        ...          ...             ...
# 4898          0.8  0.818182   0.009283     0.239141        0.042495
# 4899          0.8  0.863636   0.009359     0.227311        0.037176
# 4900          0.8  0.909091   0.009495     0.235377        0.053134
# 4901          0.8  0.954545   0.009700     0.246131        0.070612
# 4902          0.8  1.000000   0.009966     0.232688        0.069852
#
#       e_prev_100k_hi  e_prev_num  e_prev_num_lo  e_prev_num_hi  \
# 0           0.183607    0.008261       0.003250       0.014808
# ...
